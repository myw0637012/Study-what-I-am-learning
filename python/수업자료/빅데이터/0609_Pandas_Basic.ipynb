# %%
import pandas as pd
xtrain = pd.read_csv("X_train.csv", encoding="cp949", parse_dates=["date_time"])
xtrain
# Out:
#          custid           date_time store        product  brand   corner  \
# 0             0 2000-06-25 12:12:00   무역점  2116050008000  에스티로더  수입종합화장품
# 1             0 2000-06-25 12:42:00   무역점  4125440008000    시슬리  수입종합화장품
# 2             0 2000-08-26 18:10:00    본점  2116052008000   크리니크  수입종합화장품
# 3             0 2000-08-26 18:30:00    본점  4106430119900     듀퐁     수입의류
# 4             0 2000-09-03 18:02:00   무역점  2139141008000     랑콤  수입종합화장품
# ...         ...                 ...   ...            ...    ...      ...
# 1036648   29998 2001-01-21 13:20:00   무역점  4241080013074    바닐라     영캐주얼
# 1036649   29998 2001-04-07 16:33:00   무역점  2139141008000     랑콤  수입종합화장품
# 1036650   29999 2001-03-21 18:03:00   천호점  4109290004000  루이까또즈      핸드백
# 1036651   29999 2001-03-29 18:23:00   천호점  4139350206500  소피에르핀      넥타이
# 1036652   29999 2001-04-21 13:13:00   천호점  4104840008000     샤넬  수입종합화장품
#
#               pc   part  imported  amount  discount  installment
# ...

# %%
xtrain.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1036653 entries, 0 to 1036652
# Data columns (total 12 columns):
#  #   Column       Non-Null Count    Dtype
# ---  ------       --------------    -----
#  0   custid       1036653 non-null  int64
#  1   date_time    1036653 non-null  datetime64[ns]
#  2   store        1036653 non-null  object
#  3   product      1036653 non-null  int64
#  4   brand        1036653 non-null  object
#  5   corner       1036653 non-null  object
#  6   pc           1036653 non-null  object
#  7   part         1036653 non-null  object
#  8   imported     1036653 non-null  int64
#  9   amount       1036653 non-null  int64
#  10  discount     1036653 non-null  int64
#  11  installment  1036653 non-null  int64
# dtypes: datetime64[ns](1), int64(6), object(5)
# memory usage: 94.9+ MB

# %%
xtrain['Date'] = xtrain['date_time'].dt.date

# %%
xtrain.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1036653 entries, 0 to 1036652
# Data columns (total 15 columns):
#  #   Column       Non-Null Count    Dtype
# ---  ------       --------------    -----
#  0   custid       1036653 non-null  int64
#  1   date_time    1036653 non-null  datetime64[ns]
#  2   store        1036653 non-null  object
#  3   product      1036653 non-null  int64
#  4   brand        1036653 non-null  object
#  5   corner       1036653 non-null  object
#  6   pc           1036653 non-null  object
#  7   part         1036653 non-null  object
#  8   imported     1036653 non-null  int64
#  9   amount       1036653 non-null  int64
#  10  discount     1036653 non-null  int64
#  11  installment  1036653 non-null  int64
#  12  Date         1036653 non-null  datetime64[ns]
#  13  Year         1036653 non-null  int64
#  14  Month        1036653 non-null  int64
# dtypes: datetime64[ns](2), int64(8), object(5)
# memory usage: 118.6+ MB

# %%
xtrain['Date'] = xtrain['Date'].astype('datetime64[ns]')

# %%
xtrain.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1036653 entries, 0 to 1036652
# Data columns (total 13 columns):
#  #   Column       Non-Null Count    Dtype
# ---  ------       --------------    -----
#  0   custid       1036653 non-null  int64
#  1   date_time    1036653 non-null  datetime64[ns]
#  2   store        1036653 non-null  object
#  3   product      1036653 non-null  int64
#  4   brand        1036653 non-null  object
#  5   corner       1036653 non-null  object
#  6   pc           1036653 non-null  object
#  7   part         1036653 non-null  object
#  8   imported     1036653 non-null  int64
#  9   amount       1036653 non-null  int64
#  10  discount     1036653 non-null  int64
#  11  installment  1036653 non-null  int64
#  12  Date         1036653 non-null  datetime64[ns]
# dtypes: datetime64[ns](2), int64(6), object(5)
# memory usage: 102.8+ MB

# %%
xtrain['Year'] = xtrain['Date'].dt.year

# %%
xtrain.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1036653 entries, 0 to 1036652
# Data columns (total 14 columns):
#  #   Column       Non-Null Count    Dtype
# ---  ------       --------------    -----
#  0   custid       1036653 non-null  int64
#  1   date_time    1036653 non-null  datetime64[ns]
#  2   store        1036653 non-null  object
#  3   product      1036653 non-null  int64
#  4   brand        1036653 non-null  object
#  5   corner       1036653 non-null  object
#  6   pc           1036653 non-null  object
#  7   part         1036653 non-null  object
#  8   imported     1036653 non-null  int64
#  9   amount       1036653 non-null  int64
#  10  discount     1036653 non-null  int64
#  11  installment  1036653 non-null  int64
#  12  Date         1036653 non-null  datetime64[ns]
#  13  Year         1036653 non-null  int64
# dtypes: datetime64[ns](2), int64(7), object(5)
# memory usage: 110.7+ MB

# %%
xtrain['Month'] = xtrain['Date'].dt.month

# %%
xtrain.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1036653 entries, 0 to 1036652
# Data columns (total 15 columns):
#  #   Column       Non-Null Count    Dtype
# ---  ------       --------------    -----
#  0   custid       1036653 non-null  int64
#  1   date_time    1036653 non-null  datetime64[ns]
#  2   store        1036653 non-null  object
#  3   product      1036653 non-null  int64
#  4   brand        1036653 non-null  object
#  5   corner       1036653 non-null  object
#  6   pc           1036653 non-null  object
#  7   part         1036653 non-null  object
#  8   imported     1036653 non-null  int64
#  9   amount       1036653 non-null  int64
#  10  discount     1036653 non-null  int64
#  11  installment  1036653 non-null  int64
#  12  Date         1036653 non-null  datetime64[ns]
#  13  Year         1036653 non-null  int64
#  14  Month        1036653 non-null  int64
# dtypes: datetime64[ns](2), int64(8), object(5)
# memory usage: 118.6+ MB

# %%
xtrain
# Out:
#          custid           date_time store        product  brand   corner  \
# 0             0 2000-06-25 12:12:00   무역점  2116050008000  에스티로더  수입종합화장품
# 1             0 2000-06-25 12:42:00   무역점  4125440008000    시슬리  수입종합화장품
# 2             0 2000-08-26 18:10:00    본점  2116052008000   크리니크  수입종합화장품
# 3             0 2000-08-26 18:30:00    본점  4106430119900     듀퐁     수입의류
# 4             0 2000-09-03 18:02:00   무역점  2139141008000     랑콤  수입종합화장품
# ...         ...                 ...   ...            ...    ...      ...
# 1036648   29998 2001-01-21 13:20:00   무역점  4241080013074    바닐라     영캐주얼
# 1036649   29998 2001-04-07 16:33:00   무역점  2139141008000     랑콤  수입종합화장품
# 1036650   29999 2001-03-21 18:03:00   천호점  4109290004000  루이까또즈      핸드백
# 1036651   29999 2001-03-29 18:23:00   천호점  4139350206500  소피에르핀      넥타이
# 1036652   29999 2001-04-21 13:13:00   천호점  4104840008000     샤넬  수입종합화장품
#
#               pc   part  imported  amount  discount  installment       Date  \
# ...

# %%
brand = xtrain.groupby(["brand", "Year"])
brand.agg({"amount":["sum","mean"]})
# Out:
#                  amount
#                     sum          mean
# brand   Year
# 012베네통  2000  108160970  6.241256e+04
#         2001   49182500  5.932750e+04
# 1492    2000   29530200  5.635534e+04
#         2001   14140500  5.795287e+04
# 1492마일즈 2000   38232300  5.881892e+04
# ...                 ...           ...
# 휴먼앤휴먼   2000     596200  5.420000e+04
# 흙침대     2000   26904320  2.069563e+06
#         2001    7173160  1.434632e+06
# 희원상사    2000    1372000  6.860000e+04
#         2001     347000  1.156667e+05
#
# [3150 rows x 2 columns]

# %%
esti = xtrain["brand"] =="에스티로더"

# %%
xtrain[esti]
# Out:
#          custid           date_time store        product  brand   corner   pc  \
# 0             0 2000-06-25 12:12:00   무역점  2116050008000  에스티로더  수입종합화장품  화장품
# 201           9 2000-06-05 19:23:00   무역점  2116050008000  에스티로더  수입종합화장품  화장품
# 258          10 2000-05-16 10:30:00    본점  2116050008000  에스티로더  수입종합화장품  화장품
# 260          10 2000-05-31 18:20:00    본점  2116050008000  에스티로더  수입종합화장품  화장품
# 265          10 2000-06-27 10:40:00    본점  2116050008000  에스티로더  수입종합화장품  화장품
# ...         ...                 ...   ...            ...    ...      ...  ...
# 1035956   29976 2000-09-07 18:00:00   무역점  2116050008000  에스티로더  수입종합화장품  화장품
# 1036309   29986 2001-04-24 17:10:00    본점  2116050008000  에스티로더  수입종합화장품  화장품
# 1036390   29989 2000-12-04 16:23:00   신촌점  2116050008000  에스티로더  수입종합화장품  화장품
# 1036391   29989 2000-12-19 16:33:00   무역점  2116050008000  에스티로더  수입종합화장품  화장품
# 1036506   29994 2000-12-14 16:03:00   무역점  2116050008000  에스티로더  수입종합화장품  화장품
#
# ...

# %%
week1 = pd.read_csv("Restaurant - Week 1 Sales.csv")
week2 = pd.read_csv("Restaurant - Week 2 Sales.csv")
customer = pd.read_csv("Restaurant - Customers.csv")
food = pd.read_csv("Restaurant - Foods.csv")

# %%
len(week1)
# Out:
# 250

# %%
len(week2)
# Out:
# 250

# %%
len(customer)
# Out:
# 1000

# %%
len(food)
# Out:
# 10

# %%
len(pd.concat([week1, week2]))
# Out:
# 500

# %%
week1
# Out:
#      Customer ID  Food ID
# 0            537        9
# 1             97        4
# 2            658        1
# 3            202        2
# 4            155        9
# ..           ...      ...
# 245          413        9
# 246          926        6
# 247          134        3
# 248          396        6
# 249          535       10
#
# [250 rows x 2 columns]

# %%
pd.concat([week1, week2], keys=["A", "B"])
# Out:
#        Customer ID  Food ID
# A 0            537        9
#   1             97        4
#   2            658        1
#   3            202        2
#   4            155        9
# ...            ...      ...
# B 245          783       10
#   246          556       10
#   247          547        9
#   248          252        9
#   249          249        6
#
# [500 rows x 2 columns]

# %%
week1 = pd.read_csv("Restaurant - Week 1 Sales.csv")
week2 = pd.read_csv("Restaurant - Week 2 Sales.csv")
customer = pd.read_csv("Restaurant - Customers.csv")
food = pd.read_csv("Restaurant - Foods.csv")

# %%
sales = week2.append(week1, ignore_index = True)

# %%
sales
# Out:
#      Customer ID  Food ID
# 0            688       10
# 1            813        7
# 2            495       10
# 3            189        5
# 4            267        3
# ..           ...      ...
# 495          413        9
# 496          926        6
# 497          134        3
# 498          396        6
# 499          535       10
#
# [500 rows x 2 columns]

# %% [markdown]
# # Join

# %%
week1 = pd.read_csv("Restaurant - Week 1 Sales.csv")
week2 = pd.read_csv("Restaurant - Week 2 Sales.csv")
customer = pd.read_csv("Restaurant - Customers.csv")
food = pd.read_csv("Restaurant - Foods.csv")

# %%
week1.merge(week2)
# Out:
#    Customer ID  Food ID
# 0          304        3
# 1          540        3
# 2          937       10
# 3          233        3
# 4           21        4
# 5           21        4
# 6          922        1
# 7          578        5
# 8          578        5

# %%
week1.merge(week2, how = 'outer', on = "Customer ID")
# Out:
#      Customer ID  Food ID_x  Food ID_y
# 0            537        9.0        5.0
# 1             97        4.0        NaN
# 2            658        1.0        NaN
# 3            202        2.0        NaN
# 4            155        9.0        3.0
# ..           ...        ...        ...
# 449          855        NaN        4.0
# 450          559        NaN       10.0
# 451          276        NaN        4.0
# 452          556        NaN       10.0
# 453          252        NaN        9.0
#
# [454 rows x 3 columns]

# %%
week1
# Out:
#      Customer ID  Food ID
# 0            537        9
# 1             97        4
# 2            658        1
# 3            202        2
# 4            155        9
# ..           ...      ...
# 245          413        9
# 246          926        6
# 247          134        3
# 248          396        6
# 249          535       10
#
# [250 rows x 2 columns]

# %%
week1.merge(week2, how = 'outer', on = "Customer ID", suffixes = ["-A", "-B"])
# Out:
#      Customer ID  Food ID-A  Food ID-B
# 0            537        9.0        5.0
# 1             97        4.0        NaN
# 2            658        1.0        NaN
# 3            202        2.0        NaN
# 4            155        9.0        3.0
# ..           ...        ...        ...
# 449          855        NaN        4.0
# 450          559        NaN       10.0
# 451          276        NaN        4.0
# 452          556        NaN       10.0
# 453          252        NaN        9.0
#
# [454 rows x 3 columns]

# %%
week1[week1["Customer ID"] == 100]
# Out:
#      Customer ID  Food ID
# 45           100        1
# 135          100        7
# 207          100        4

# %%
week1 = pd.read_csv("Restaurant - Week 1 Sales.csv")
week2 = pd.read_csv("Restaurant - Week 2 Sales.csv")
customer = pd.read_csv("Restaurant - Customers.csv")
food = pd.read_csv("Restaurant - Foods.csv")

# %%
week1.merge(week2, on = ["Customer ID", "Food ID"])
# Out:
#    Customer ID  Food ID
# 0          304        3
# 1          540        3
# 2          937       10
# 3          233        3
# 4           21        4
# 5           21        4
# 6          922        1
# 7          578        5
# 8          578        5

# %%
week1.merge(week2, how = "outer", on = ["Customer ID", "Food ID"])
# Out:
#      Customer ID  Food ID
# 0            537        9
# 1             97        4
# 2            658        1
# 3            202        2
# 4            155        9
# ..           ...      ...
# 488          783       10
# 489          556       10
# 490          547        9
# 491          252        9
# 492          249        6
#
# [493 rows x 2 columns]

# %%
week1.merge(week2, how = "outer", on = ["Customer ID", "Food ID"], suffixes = ["-MM", "-B"], indicator = False)
# Out:
#      Customer ID  Food ID
# 0            537        9
# 1             97        4
# 2            658        1
# 3            202        2
# 4            155        9
# ..           ...      ...
# 488          783       10
# 489          556       10
# 490          547        9
# 491          252        9
# 492          249        6
#
# [493 rows x 2 columns]

# %%
week1.merge(week2, how = "outer", on = ["Customer ID", "Food ID"], suffixes = ["-MM", "-B"], indicator = True)
# Out:
#      Customer ID  Food ID      _merge
# 0            537        9   left_only
# 1             97        4   left_only
# 2            658        1   left_only
# 3            202        2   left_only
# 4            155        9   left_only
# ..           ...      ...         ...
# 488          783       10  right_only
# 489          556       10  right_only
# 490          547        9  right_only
# 491          252        9  right_only
# 492          249        6  right_only
#
# [493 rows x 3 columns]

# %%
week1.merge(week2, how = "outer", on = "Customer ID", suffixes = ["-MM", "-B"], indicator = True)
# Out:
#      Customer ID  Food ID-MM  Food ID-B      _merge
# 0            537         9.0        5.0        both
# 1             97         4.0        NaN   left_only
# 2            658         1.0        NaN   left_only
# 3            202         2.0        NaN   left_only
# 4            155         9.0        3.0        both
# ..           ...         ...        ...         ...
# 449          855         NaN        4.0  right_only
# 450          559         NaN       10.0  right_only
# 451          276         NaN        4.0  right_only
# 452          556         NaN       10.0  right_only
# 453          252         NaN        9.0  right_only
#
# [454 rows x 4 columns]

# %%
week1 = pd.read_csv("Restaurant - Week 1 Sales.csv")
week2 = pd.read_csv("Restaurant - Week 2 Sales.csv")
customer = pd.read_csv("Restaurant - Customers.csv")
food = pd.read_csv("Restaurant - Foods.csv")

# %%
week1.merge(week2, how = "left", on = ["Customer ID", "Food ID"], indicator = True)
# Out:
#      Customer ID  Food ID     _merge
# 0            537        9  left_only
# 1             97        4  left_only
# 2            658        1  left_only
# 3            202        2  left_only
# 4            155        9  left_only
# ..           ...      ...        ...
# 246          413        9  left_only
# 247          926        6  left_only
# 248          134        3  left_only
# 249          396        6  left_only
# 250          535       10  left_only
#
# [251 rows x 3 columns]

# %%
week1.merge(week2, how = "right", on = ["Customer ID", "Food ID"], indicator = True)
# Out:
#      Customer ID  Food ID      _merge
# 0            304        3        both
# 1            540        3        both
# 2            937       10        both
# 3            233        3        both
# 4             21        4        both
# ..           ...      ...         ...
# 246          783       10  right_only
# 247          556       10  right_only
# 248          547        9  right_only
# 249          252        9  right_only
# 250          249        6  right_only
#
# [251 rows x 3 columns]

# %%
week1.merge(week2, how = "outer", on = ["Customer ID", "Food ID"], indicator = True)
# Out:
#      Customer ID  Food ID      _merge
# 0            537        9   left_only
# 1             97        4   left_only
# 2            658        1   left_only
# 3            202        2   left_only
# 4            155        9   left_only
# ..           ...      ...         ...
# 488          783       10  right_only
# 489          556       10  right_only
# 490          547        9  right_only
# 491          252        9  right_only
# 492          249        6  right_only
#
# [493 rows x 3 columns]

# %%
week1 = pd.read_csv("Restaurant - Week 1 Sales.csv")
week2 = pd.read_csv("Restaurant - Week 2 Sales.csv")
customer = pd.read_csv("Restaurant - Customers.csv")
food = pd.read_csv("Restaurant - Foods.csv")

# %%
food.head()
# Out:
#    Food ID   Food Item  Price
# 0        1       Sushi   3.99
# 1        2     Burrito   9.99
# 2        3        Taco   2.99
# 3        4  Quesadilla   4.25
# 4        5       Pizza   2.49

# %%
sales.head()
# Out:
#    Customer ID  Food ID
# 0          688       10
# 1          813        7
# 2          495       10
# 3          189        5
# 4          267        3

# %%
sales = sales.merge(food, how="left", left_on = "Food ID", right_index = True)

# %%
sales
# Out:
#      Customer ID  Food ID_x  Food ID_y   Food Item  Price
# 0            688         10        NaN         NaN    NaN
# 1            813          7        8.0       Salad  11.25
# 2            495         10        NaN         NaN    NaN
# 3            189          5        6.0       Pasta  13.99
# 4            267          3        4.0  Quesadilla   4.25
# ..           ...        ...        ...         ...    ...
# 495          413          9       10.0       Drink   1.75
# 496          926          6        7.0       Steak  24.99
# 497          134          3        4.0  Quesadilla   4.25
# 498          396          6        7.0       Steak  24.99
# 499          535         10        NaN         NaN    NaN
#
# [500 rows x 5 columns]

# %%
bond = pd.read_csv("jamesbond.csv")

# %%
bond.head()
# Out:
#                     Film  Year         Actor       Director  Box Office  \
# 0                 Dr. No  1962  Sean Connery  Terence Young       448.8
# 1  From Russia with Love  1963  Sean Connery  Terence Young       543.8
# 2             Goldfinger  1964  Sean Connery   Guy Hamilton       820.4
# 3            Thunderball  1965  Sean Connery  Terence Young       848.1
# 4          Casino Royale  1967   David Niven     Ken Hughes       315.0
#
#    Budget  Bond Actor Salary
# 0     7.0                0.6
# 1    12.6                1.6
# 2    18.6                3.2
# 3    41.9                4.7
# 4    85.0                NaN

# %%
bond.set_index("Film", inplace=True)

# %%
bond.head()
# Out:
#                        Year         Actor       Director  Box Office  Budget  \
# Film
# Dr. No                 1962  Sean Connery  Terence Young       448.8     7.0
# From Russia with Love  1963  Sean Connery  Terence Young       543.8    12.6
# Goldfinger             1964  Sean Connery   Guy Hamilton       820.4    18.6
# Thunderball            1965  Sean Connery  Terence Young       848.1    41.9
# Casino Royale          1967   David Niven     Ken Hughes       315.0    85.0
#
#                        Bond Actor Salary
# Film
# Dr. No                               0.6
# From Russia with Love                1.6
# Goldfinger                           3.2
# Thunderball                          4.7
# Casino Royale                        NaN

# %%
bond.reset_index(drop=False, inplace=True)
bond.head()
# Out:
#                     Film  Year         Actor       Director  Box Office  \
# 0                 Dr. No  1962  Sean Connery  Terence Young       448.8
# 1  From Russia with Love  1963  Sean Connery  Terence Young       543.8
# 2             Goldfinger  1964  Sean Connery   Guy Hamilton       820.4
# 3            Thunderball  1965  Sean Connery  Terence Young       848.1
# 4          Casino Royale  1967   David Niven     Ken Hughes       315.0
#
#    Budget  Bond Actor Salary
# 0     7.0                0.6
# 1    12.6                1.6
# 2    18.6                3.2
# 3    41.9                4.7
# 4    85.0                NaN

# %%
bond = pd.read_csv("jamesbond.csv")
bond.sort_index(inplace=True)
bond.head()
# Out:
#                     Film  Year         Actor       Director  Box Office  \
# 0                 Dr. No  1962  Sean Connery  Terence Young       448.8
# 1  From Russia with Love  1963  Sean Connery  Terence Young       543.8
# 2             Goldfinger  1964  Sean Connery   Guy Hamilton       820.4
# 3            Thunderball  1965  Sean Connery  Terence Young       848.1
# 4          Casino Royale  1967   David Niven     Ken Hughes       315.0
#
#    Budget  Bond Actor Salary
# 0     7.0                0.6
# 1    12.6                1.6
# 2    18.6                3.2
# 3    41.9                4.7
# 4    85.0                NaN

# %%
bond = pd.read_csv("jamesbond.csv")

# %%
bond.set_index("Film", inplace=True)

# %%
bond.loc["Goldfinger"]
# Out:
# Year                         1964
# Actor                Sean Connery
# Director             Guy Hamilton
# Box Office                  820.4
# Budget                       18.6
# Bond Actor Salary             3.2
# Name: Goldfinger, dtype: object

# %%
bond.loc["GoldenEye":"Skyfall"]
# Out:
#                          Year           Actor            Director  Box Office  \
# Film
# GoldenEye                1995  Pierce Brosnan     Martin Campbell       518.5
# Tomorrow Never Dies      1997  Pierce Brosnan  Roger Spottiswoode       463.2
# The World Is Not Enough  1999  Pierce Brosnan       Michael Apted       439.5
# Die Another Day          2002  Pierce Brosnan        Lee Tamahori       465.4
# Casino Royale            2006    Daniel Craig     Martin Campbell       581.5
# Quantum of Solace        2008    Daniel Craig        Marc Forster       514.2
# Skyfall                  2012    Daniel Craig          Sam Mendes       943.5
#
#                          Budget  Bond Actor Salary
# Film
# GoldenEye                  76.9                5.1
# Tomorrow Never Dies       133.9               10.0
# The World Is Not Enough   158.3               13.5
# Die Another Day           154.2               17.9
# Casino Royale             145.3                3.3
# ...

# %%
"GoldenEye" in bond.index
# Out:
# True

# %%
bond.reset_index(drop=False, inplace=True)
bond
# Out:
#                     Film  Year         Actor       Director  Box Office  \
# 0                 Dr. No  1962  Sean Connery  Terence Young       448.8
# 1  From Russia with Love  1963  Sean Connery  Terence Young       543.8
# 2             Goldfinger  1964  Sean Connery   Guy Hamilton       820.4
# 3            Thunderball  1965  Sean Connery  Terence Young       848.1
# 4          Casino Royale  1967   David Niven     Ken Hughes       315.0
#
#    Budget  Bond Actor Salary
# 0     7.0                0.6
# 1    12.6                1.6
# 2    18.6                3.2
# 3    41.9                4.7
# 4    85.0                NaN

# %%
bond
# Out:
#                                Film  Year           Actor            Director  \
# 0                            Dr. No  1962    Sean Connery       Terence Young
# 1             From Russia with Love  1963    Sean Connery       Terence Young
# 2                        Goldfinger  1964    Sean Connery        Guy Hamilton
# 3                       Thunderball  1965    Sean Connery       Terence Young
# 4                     Casino Royale  1967     David Niven          Ken Hughes
# 5               You Only Live Twice  1967    Sean Connery       Lewis Gilbert
# 6   On Her Majesty's Secret Service  1969  George Lazenby       Peter R. Hunt
# 7              Diamonds Are Forever  1971    Sean Connery        Guy Hamilton
# 8                  Live and Let Die  1973     Roger Moore        Guy Hamilton
# 9       The Man with the Golden Gun  1974     Roger Moore        Guy Hamilton
# 10             The Spy Who Loved Me  1977     Roger Moore       Lewis Gilbert
# ...

# %%
bond.iloc[[5,10,7]]
# Out:
#                     Film  Year         Actor       Director  Box Office  \
# 5    You Only Live Twice  1967  Sean Connery  Lewis Gilbert       514.2
# 10  The Spy Who Loved Me  1977   Roger Moore  Lewis Gilbert       533.0
# 7   Diamonds Are Forever  1971  Sean Connery   Guy Hamilton       442.5
#
#     Budget  Bond Actor Salary
# 5     59.9                4.4
# 10    45.1                NaN
# 7     34.7                5.8

# %%
bond.loc[3]
# Out:
# Film                   Thunderball
# Year                          1965
# Actor                 Sean Connery
# Director             Terence Young
# Box Office                   848.1
# Budget                        41.9
# Bond Actor Salary              4.7
# Name: 3, dtype: object

# %%
bond.loc[[5,10,7]]
# Out:
#                     Film  Year         Actor       Director  Box Office  \
# 5    You Only Live Twice  1967  Sean Connery  Lewis Gilbert       514.2
# 10  The Spy Who Loved Me  1977   Roger Moore  Lewis Gilbert       533.0
# 7   Diamonds Are Forever  1971  Sean Connery   Guy Hamilton       442.5
#
#     Budget  Bond Actor Salary
# 5     59.9                4.4
# 10    45.1                NaN
# 7     34.7                5.8
