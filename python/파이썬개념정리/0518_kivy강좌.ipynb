# %%
# %%writefile main.py
##키비 교육_0518
from kivy.app import App
from kivy.uix.button import Label
from kivy.config import Config

Config.set('graphics','width','200')
Config.set('graphics','height','200')

class TestApp(App):
    def build(self):
        self.title = 'Windows Sample'
        self.icon = 'mario.png'
        return Label(text='Hello World')
    
TestApp().run()
# Out:
# Overwriting main.py

# %%
# !Ipython main.py
# Out:
# ^C

# %%
# %%writefile main.py
from kivy.app import App
from kivy.uix.button import Label, Button
from kivy.config import Config
from kivy.uix.actionbar import ActionBar, ActionItem, ActionView, ActionPrevious, ActionGroup, ActionButton
from kivy.uix.floatlayout import FloatLayout

Config.set('graphics','width','200')
Config.set('graphics','height','200')

class MyActionBar():
    def __init__(self):
        actionview = ActionView()
        actionview.use_seperator=True
        ap = ActionPrevious(title='Action Bar', with_previous=False)
        actionview.add_widget(ap)
        
        self.abtn1 = ActionButton(text='Btn1')
        self.abtn1.bind(on_press = self.ActionBtn1Callback)
        actionview.add_widget(self.abtn1)

        self.abtn2 = ActionButton(text='Btn2')
        self.abtn2.bind(on_press = self.ActionBtn2Callback)
        actionview.add_widget(self.abtn2)
        
        self.abtn3 = ActionButton(text='Btn3', icon='mario.png')
        self.abtn3.bind(on_press = self.ActionBtn3Callback)
        actionview.add_widget(self.abtn3)

        
        group1 = ActionGroup()
        
        self.abtn4 = ActionButton(text='Btn4')
        self.abtn4.bind(on_press = self.ActionBtn4Callback)
        actionview.add_widget(self.abtn4)

        
        self.abtn5 = ActionButton(text='Press check')
        self.abtn5.bind(on_press = self.ActionBtn5Callback)
        actionview.add_widget(self.abtn5)
        
        actionview.add_widget(group1)
        self.actionbar = ActionBar()
        self.actionbar.add_widget(actionview)
        
        
    def ActionBtn1Callback(self, instance):
        print('btn1')
        
    def ActionBtn2Callback(self, instance):
        print('btn2')
    
    def ActionBtn3Callback(self, instance):
        print('btn3')

    def ActionBtn4Callback(self, instance):
        print('btn4')
        
    def ActionBtn5Callback(self, instance):
        print('btn5')
        
class RootWidget(FloatLayout):
    def __init__(self, **kwargs):
        super(RootWidget, self).__init__(**kwargs)
        
        self.add_widget(
            Button(
                text = 'Hello World',
                size_hint = (.5, .5),
                pos_hint = {'center_x' : .5, 'center_y' : .5}))
        
        self.myactionbar=MyActionBar()            
        self.add_widget(self.myactionbar.actionbar)
            
class TestApp(App):
    def build(self):
        self.root = root = RootWidget()
        self.title = 'Window Sample'
        self.icon = 'mario.png'
        return self.root
        
TestApp().run()
# Out:
# Overwriting main.py

# %%
# !Ipython main.py
# Out:
# ^C

# %%
# %%writefile main.py
from kivy.app import App
from kivy.uix.button import Label, Button
from kivy.config import Config
from kivy.uix.boxlayout import BoxLayout
from kivy.uix.textinput import TextInput
from kivy.clock import Clock
from datetime import datetime
from kivy.core.text import LabelBase, DEFAULT_FONT
from kivy.resources import resource_add_path
resource_add_path('c:/windows/fonts')
LabelBase.register(DEFAULT_FONT, 'H2GTRM.ttf')

Config.set('graphics','width','400')
Config.set('graphics','height','400')

class RootWidget(BoxLayout):
    def __init__(self, **kwargs):
        super(RootWidget, self).__init__(padding=30, orientation='vertical')
        
        self.label = Label(text='시간입력창')
        self.add_widget(self.label)
        
        Clock.schedule_interval(self.TimeCallback, 1.0)
        
        self.textinput = TextInput(text = 'hello world', multiline = False)
        self.add_widget(self.textinput)
        
    def TimeCallback(self, dt):
        time = datetime.now().strftime('%Y/%m/%d %H:%M:%S')
        self.textinput.text=time
        
class TestApp(App):
    def build(self):
        self.root = RootWidget()
        self.title = 'Test input'
        return self.root
    
TestApp().run()
# Out:
# Overwriting main.py

# %%
# !Ipython main.py

# %%
# %%writefile main.py
from kivy.app import App
from kivy.config import Config
from kivy.uix.boxlayout import BoxLayout
from kivy.uix.label import Label
import numpy as np
import matplotlib
matplotlib.use('module://kivy.garden.matplotlib.backend_kivy')
import matplotlib.pyplot as pl
import sys, os

class GraphView(BoxLayout):
    def __init__(self, **kwargs):
        super(GraphView, self).__init__(orientation = 'vertical')
        self.add_widget(Label(text='matplotlib sample'))
        self.add_widget(self.graph_plot_sample())
        
    def graph_plot_sample(self):
        self.fig, ax = pl.subplots()
        x = np.linspace(-np.pi, np.pi)
        y = np.sin(x)
        ax.set_xlabel('x label')
        ax.set_ylabel('y label')
        ax.grid(True)
        ax.plot(x,y)
        return self.fig.canvas
    
class GraphApp(App):
    def build(self):
        height = 300
        Config.set('graphics','width', height*2)
        Config.set('graphics','height',height)
        return GraphView()
    
if __name__ == '__main__':
    GraphApp().run()
# Out:
# Overwriting main.py

# %%
# !Ipython main.py
# Out:
# [INFO   ] [Logger      ] Record log in C:\Users\w\.kivy\logs\kivy_20-05-19_16.txt
# [INFO   ] [Kivy        ] v1.11.1
# [INFO   ] [Kivy        ] Installed at "C:\Users\w\anaconda3\lib\site-packages\kivy\__init__.py"
# [INFO   ] [Python      ] v3.7.6 (default, Jan  8 2020, 20:23:39) [MSC v.1916 64 bit (AMD64)]
# [INFO   ] [Python      ] Interpreter at "C:\Users\w\anaconda3\python.exe"
# [INFO   ] [Factory     ] 184 symbols loaded
# [INFO   ] [Image       ] Providers: img_tex, img_dds, img_sdl2, img_pil, img_gif (img_ffpyplayer ignored)
# [INFO   ] [Text        ] Provider: sdl2
# [INFO   ] [Window      ] Provider: sdl2
# [INFO   ] [GL          ] Using the "OpenGL" graphics system
# [INFO   ] [GL          ] GLEW initialization succeeded
# [INFO   ] [GL          ] Backend used <glew>
# [INFO   ] [GL          ] OpenGL version <b'4.6.0 - Build 26.20.100.7262'>
# [INFO   ] [GL          ] OpenGL vendor <b'Intel'>
# [INFO   ] [GL          ] OpenGL renderer <b'Intel(R) HD Graphics 530'>
# ...

# %%
# %%writefile main.py
from kivy.garden.mapview import MapView
from kivy.garden.mapview import MapMarkerPopup
from kivy.app import App

class MapViewApp(App):
    def build(self):
        mapview = MapView(zoom = 15, lat = 35.8762169, lon=128.6285781)
        marker1 = MapMarkerPopup(lat=35.8762169, lon=128.6285781)
        mapview.add_marker(marker1)
        return mapview

MapViewApp().run()

# %%
# !Ipython main.py

# %%
#그래프 그릴때의 기본
import numpy as np #숫자연산처리(행렬연산), 그래픽연산
import pandas as pd #dataframe처리, 단 대용량 처리는 spark로 처리함(hadoop에 100배빠름)
import seaborn as sns #그래픽 이쁘게
from collections import Counter
import matplotlib.pyplot as plt #그래프 라이브러리
# %matplotlib inline #seaborn하고 같이 씀, 그래프 불러들일때
# Out:
# UsageError: unrecognized arguments: #seaborn하고 같이 씀, 그래프 불러들일때

# %%
#그래프에 한글적용하는 방법
from matplotlib import font_manager, rc
font_name = font_manager.FontProperties(fname='c:/windows/fonts/malgun.ttf').get_name()
rc('font', family=font_name)

# %%
https://data.census.gov/cedsci/
# Out:
#   File "<ipython-input-15-4f5b2d615010>", line 1
#     https://data.census.gov/cedsci/
#            ^
# SyntaxError: invalid syntax

# %%
poverty_level = pd.read_csv('C:/Users/w/PercentagePeopleBelowPovertyLevel.csv', encoding='windows-1252')

# %%
poverty_level.head(50) #tail - 뒤에서 보여줌
# Out:
#    Geographic Area                 City poverty_rate
# 0               AL           Abanda CDP         78.8
# 1               AL       Abbeville city         29.1
# 2               AL      Adamsville city         25.5
# 3               AL         Addison town         30.7
# 4               AL           Akron town           42
# 5               AL       Alabaster city         11.2
# 6               AL     Albertville city         26.7
# 7               AL  Alexander City city         30.4
# 8               AL       Alexandria CDP          9.7
# 9               AL      Aliceville city         41.3
# 10              AL         Allgood town         27.7
# 11              AL         Altoona town         27.5
# 12              AL       Andalusia city         24.5
# 13              AL        Anderson town         13.8
# 14              AL        Anniston city         31.7
# 15              AL            Arab city         16.7
# 16              AL         Ardmore town         19.1
# ...

# %%
poverty_level.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29329 entries, 0 to 29328
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Geographic Area  29329 non-null  object
#  1   City             29329 non-null  object
#  2   poverty_rate     29329 non-null  object
# dtypes: object(3)
# memory usage: 687.5+ KB

# %%
poverty_level.poverty_rate.replace(['-'],0.0, inplace=True)

# %%
poverty_level.poverty_rate.dtype
# Out:
# dtype('O')

# %%
poverty_level.poverty_rate.all
# Out:
# <bound method Series.all of 0        78.8
# 1        29.1
# 2        25.5
# 3        30.7
# 4          42
#          ...
# 29324    18.6
# 29325    15.3
# 29326     5.9
# 29327     5.4
# 29328       0
# Name: poverty_rate, Length: 29329, dtype: object>

# %%
poverty_level.poverty_rate # float와 int가 섞여있음
# Out:
# 0        78.8
# 1        29.1
# 2        25.5
# 3        30.7
# 4          42
#          ...
# 29324    18.6
# 29325    15.3
# 29326     5.9
# 29327     5.4
# 29328       0
# Name: poverty_rate, Length: 29329, dtype: object

# %%
poverty_level.poverty_rate = poverty_level.poverty_rate.astype(float)
#float로 변경

# %%
poverty_level.poverty_rate.dtype
# Out:
# dtype('float64')

# %%
poverty_level.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29329 entries, 0 to 29328
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Geographic Area  29329 non-null  object
#  1   City             29329 non-null  object
#  2   poverty_rate     29329 non-null  float64
# dtypes: float64(1), object(2)
# memory usage: 687.5+ KB

# %%
area_list = list(poverty_level['Geographic Area'].unique())

# %%
area_list
# Out:
# ['AL',
#  'AK',
#  'AZ',
#  'AR',
#  'CA',
#  'CO',
#  'CT',
#  'DE',
#  'DC',
#  'FL',
#  'GA',
#  'HI',
#  'ID',
#  'IL',
#  'IN',
#  'IA',
#  'KS',
#  'KY',
#  'LA',
#  'ME',
#  'MD',
#  'MA',
#  'MI',
#  'MN',
#  'MS',
#  'MO',
#  'MT',
#  'NE',
#  'NV',
#  'NH',
#  'NJ',
#  'NM',
#  'NY',
#  'NC',
#  'ND',
#  'OH',
#  'OK',
#  'OR',
#  'PA',
#  'RI',
#  'SC',
#  'SD',
#  'TN',
#  'TX',
#  'UT',
#  'VT',
#  'VA',
#  'WA',
#  'WV',
#  'WI',
#  'WY']

# %%
#각주마다 빈곤율 평균값을 구함
area_poverty_ratio = []
for i in area_list:
    x = poverty_level[poverty_level['Geographic Area']== i]
    print(x)
    area_poverty_rate = sum(x.poverty_rate)/len(x)
    print(area_poverty_rate)
    area_poverty_ratio.append(area_poverty_rate)
# Out:
#     Geographic Area               City  poverty_rate
# 0                AL         Abanda CDP          78.8
# 1                AL     Abbeville city          29.1
# 2                AL    Adamsville city          25.5
# 3                AL       Addison town          30.7
# 4                AL         Akron town          42.0
# ..              ...                ...           ...
# 580              AL      Woodland town          26.6
# 581              AL     Woodstock town          13.5
# 582              AL     Woodville town          25.9
# 583              AL  Yellow Bluff town          44.1
# 584              AL          York city          46.8
#
# [585 rows x 3 columns]
# 20.611794871794878
#     Geographic Area                       City  poverty_rate
# 585              AK                  Adak city          39.3
# 586              AK                Akhiok city          40.5
# 587              AK               Akiachak CDP          26.1
# ...

# %%
data = pd.DataFrame({'area_list': area_list, 'area_poverty_ratio': area_poverty_ratio})

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 2 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   area_list           51 non-null     object
#  1   area_poverty_ratio  51 non-null     float64
# dtypes: float64(1), object(1)
# memory usage: 944.0+ bytes

# %%
print(data)
# Out:
#    area_list  area_poverty_ratio
# 0         AL           20.611795
# 1         AK           18.678592
# 2         AZ           25.268071
# 3         AR           22.963216
# 4         CA           16.888371
# 5         CO           13.187773
# 6         CT            9.137500
# 7         DE           12.555844
# 8         DC           18.000000
# 9         FL           17.508606
# 10        GA           23.663636
# 11        HI           13.400662
# 12        ID           18.076211
# 13        IL           13.849342
# 14        IN           15.499853
# 15        IA           12.231548
# 16        KS           14.719048
# 17        KY           20.080000
# 18        LA           22.291772
# 19        ME           16.893846
# 20        MD           10.272394
# 21        MA            9.546341
# 22        MI           17.900723
# 23        MN           13.745736
# 24        MS           26.884254
# 25        MO           19.930687
# 26        MT           16.423288
# ...

# %%
new_index = (data['area_poverty_ratio'].sort_values(ascending=False)).index.values

# %%
new_index
# Out:
# array([24,  2, 10,  3, 31, 18, 40, 48,  0, 36, 17, 25, 42, 33, 43,  1, 12,
#         8, 22,  9, 19,  4, 37, 26, 41, 14, 35, 47, 16, 46, 13, 45, 23, 11,
#         5, 27, 49, 29,  7, 38, 28, 15, 34, 44, 32, 39, 20, 21,  6, 50, 30],
#       dtype=int64)

# %%
sorted_data = data.reindex(new_index)

# %%
data
# Out:
#    area_list  area_poverty_ratio
# 0         AL           20.611795
# 1         AK           18.678592
# 2         AZ           25.268071
# 3         AR           22.963216
# 4         CA           16.888371
# 5         CO           13.187773
# 6         CT            9.137500
# 7         DE           12.555844
# 8         DC           18.000000
# 9         FL           17.508606
# 10        GA           23.663636
# 11        HI           13.400662
# 12        ID           18.076211
# 13        IL           13.849342
# 14        IN           15.499853
# 15        IA           12.231548
# 16        KS           14.719048
# 17        KY           20.080000
# 18        LA           22.291772
# 19        ME           16.893846
# 20        MD           10.272394
# 21        MA            9.546341
# 22        MI           17.900723
# 23        MN           13.745736
# 24        MS           26.884254
# 25        MO           19.930687
# 26        MT           16.423288
# ...

# %%
plt.figure(figsize=(15,10))
sns.barplot(x=sorted_data['area_list'], y=sorted_data['area_poverty_ratio'])
plt.xticks(rotation = 45)
plt.xlabel('미국의 주')
plt.ylabel('빈곤율')
plt.title('미국의 각 주마다 빈곤율')
# Out:
# Text(0.5, 1.0, '미국의 각 주마다 빈곤율')

# %%
highSchool = pd.read_csv('C:/Users/w/PercentOver25CompletedHighSchool.csv', encoding='windows-1252')

# %%
highSchool.head()
# Out:
#   Geographic Area             City percent_completed_hs
# 0              AL       Abanda CDP                 21.2
# 1              AL   Abbeville city                 69.1
# 2              AL  Adamsville city                 78.9
# 3              AL     Addison town                 81.4
# 4              AL       Akron town                 68.6

# %%
highSchool.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29329 entries, 0 to 29328
# Data columns (total 3 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Geographic Area       29329 non-null  object
#  1   City                  29329 non-null  object
#  2   percent_completed_hs  29329 non-null  object
# dtypes: object(3)
# memory usage: 687.5+ KB

# %%
highSchool.corr() # - 이 나오면 수치가 없음(object이기 때문)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
highSchool.percent_completed_hs.value_counts()
# Out:
# 100     1301
# -        197
# 91.7     170
# 92.9     169
# 92.5     168
#         ...
# 32.9       1
# 37.1       1
# 56.2       1
# 52         1
# 20.6       1
# Name: percent_completed_hs, Length: 728, dtype: int64

# %%
highSchool.percent_completed_hs.value_counts(100)
# Out:
# 100     0.044359
# -       0.006717
# 91.7    0.005796
# 92.9    0.005762
# 92.5    0.005728
#           ...
# 32.9    0.000034
# 37.1    0.000034
# 56.2    0.000034
# 52      0.000034
# 20.6    0.000034
# Name: percent_completed_hs, Length: 728, dtype: float64

# %%
highSchool.percent_completed_hs.all
# Out:
# <bound method Series.all of 0        21.2
# 1        69.1
# 2        78.9
# 3        81.4
# 4        68.6
#          ...
# 29324     100
# 29325    85.6
# 29326    89.2
# 29327    79.4
# 29328     100
# Name: percent_completed_hs, Length: 29329, dtype: object>

# %%
highSchool.percent_completed_hs.replace(['-'],0.0, inplace=True)

# %%
highSchool.percent_completed_hs = highSchool.percent_completed_hs.astype(float)

# %%
highSchool.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29329 entries, 0 to 29328
# Data columns (total 3 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Geographic Area       29329 non-null  object
#  1   City                  29329 non-null  object
#  2   percent_completed_hs  29329 non-null  float64
# dtypes: float64(1), object(2)
# memory usage: 687.5+ KB

# %%
area_list = list(highSchool['Geographic Area'].unique())

# %%
area_list
# Out:
# ['AL',
#  'AK',
#  'AZ',
#  'AR',
#  'CA',
#  'CO',
#  'CT',
#  'DE',
#  'DC',
#  'FL',
#  'GA',
#  'HI',
#  'ID',
#  'IL',
#  'IN',
#  'IA',
#  'KS',
#  'KY',
#  'LA',
#  'ME',
#  'MD',
#  'MA',
#  'MI',
#  'MN',
#  'MS',
#  'MO',
#  'MT',
#  'NE',
#  'NV',
#  'NH',
#  'NJ',
#  'NM',
#  'NY',
#  'NC',
#  'ND',
#  'OH',
#  'OK',
#  'OR',
#  'PA',
#  'RI',
#  'SC',
#  'SD',
#  'TN',
#  'TX',
#  'UT',
#  'VT',
#  'VA',
#  'WA',
#  'WV',
#  'WI',
#  'WY']

# %%
area_highschool_ratio = []
for i in area_list:
    x = highSchool[highSchool['Geographic Area']== i]
    print(x)
    area_highschool_rate = sum(x.percent_completed_hs)/len(x)
    area_highschool_ratio.append(area_highschool_rate)
    print(area_highschool_ratio)
# Out:
#     Geographic Area               City  percent_completed_hs
# 0                AL         Abanda CDP                  21.2
# 1                AL     Abbeville city                  69.1
# 2                AL    Adamsville city                  78.9
# 3                AL       Addison town                  81.4
# 4                AL         Akron town                  68.6
# ..              ...                ...                   ...
# 580              AL      Woodland town                  86.4
# 581              AL     Woodstock town                  89.5
# 582              AL     Woodville town                  77.7
# 583              AL  Yellow Bluff town                  62.0
# 584              AL          York city                  77.1
#
# [585 rows x 3 columns]
# [80.16341880341879]
#     Geographic Area                       City  percent_completed_hs
# 585              AK                  Adak city                  93.4
# ...

# %%
data = pd.DataFrame({'area_list': area_list, 
                     'area_highschool_ratio':area_highschool_ratio})
data
# Out:
#    area_list  area_highschool_ratio
# 0         AL              80.163419
# 1         AK              80.098028
# 2         AZ              79.218182
# 3         AR              79.949538
# 4         CA              80.824639
# 5         CO              88.926201
# 6         CT              91.591667
# 7         DE              88.519481
# 8         DC              89.300000
# 9         FL              85.457625
# 10        GA              78.634450
# 11        HI              91.665563
# 12        ID              84.417621
# 13        IL              88.289401
# 14        IN              86.319265
# 15        IA              89.665278
# 16        KS              87.967857
# 17        KY              82.217593
# 18        LA              79.122363
# 19        ME              91.430769
# 20        MD              88.081081
# 21        MA              92.028455
# 22        MI              89.207659
# 23        MN              89.465559
# 24        MS              78.470718
# ...

# %%
new_index = (data['area_highschool_ratio'].sort_values(ascending=False)).index.values
sorted_data1= data.reindex(new_index)
sorted_data1
# Out:
#    area_list  area_highschool_ratio
# 21        MA              92.028455
# 11        HI              91.665563
# 6         CT              91.591667
# 19        ME              91.430769
# 29        NH              90.711340
# 32        NY              90.537960
# 30        NJ              90.520550
# 49        WI              90.263964
# 26        MT              89.992603
# 45        VT              89.976860
# 15        IA              89.665278
# 44        UT              89.644615
# 27        NE              89.522414
# 23        MN              89.465559
# 8         DC              89.300000
# 22        MI              89.207659
# 38        PA              88.972872
# 5         CO              88.926201
# 39        RI              88.825000
# 7         DE              88.519481
# 13        IL              88.289401
# 35        OH              88.199177
# 20        MD              88.081081
# 16        KS              87.967857
# 37        OR              87.601857
# ...

# %%
plt.figure(figsize=(15,10))
sns.barplot(x=sorted_data1['area_list'], y=sorted_data1['area_highschool_ratio'])
plt.xticks(rotation = 45)
plt.xlabel('미국의 주')
plt.ylabel('졸업율')
plt.title('미국의 각 주마다 졸업율')
# Out:
# Text(0.5, 1.0, '미국의 각 주마다 졸업율')

# %%
sorted_data
# Out:
#    area_list  area_poverty_ratio
# 24        MS            1.000000
# 2         AZ            0.939884
# 10        GA            0.880204
# 3         AR            0.854151
# 31        NM            0.837207
# 18        LA            0.829176
# 40        SC            0.822249
# 48        WV            0.784185
# 0         AL            0.766687
# 36        OK            0.764235
# 17        KY            0.746906
# 25        MO            0.741352
# 42        TN            0.739734
# 33        NC            0.733536
# 43        TX            0.725191
# 1         AK            0.694778
# 12        ID            0.672372
# 8         DC            0.669537
# 22        MI            0.665844
# 9         FL            0.651259
# 19        ME            0.628392
# 4         CA            0.628188
# 37        OR            0.611354
# 26        MT            0.610889
# 41        SD            0.585669
# 14        IN            0.576540
# 35        OH            0.551500
# ...

# %%
sorted_data['area_poverty_ratio'] = sorted_data['area_poverty_ratio'] / max(sorted_data['area_poverty_ratio'])

# %%
sorted_data1
# Out:
#    area_list  area_highschool_ratio
# 21        MA              92.028455
# 11        HI              91.665563
# 6         CT              91.591667
# 19        ME              91.430769
# 29        NH              90.711340
# 32        NY              90.537960
# 30        NJ              90.520550
# 49        WI              90.263964
# 26        MT              89.992603
# 45        VT              89.976860
# 15        IA              89.665278
# 44        UT              89.644615
# 27        NE              89.522414
# 23        MN              89.465559
# 8         DC              89.300000
# 22        MI              89.207659
# 38        PA              88.972872
# 5         CO              88.926201
# 39        RI              88.825000
# 7         DE              88.519481
# 13        IL              88.289401
# 35        OH              88.199177
# 20        MD              88.081081
# 16        KS              87.967857
# 37        OR              87.601857
# ...

# %%
sorted_data1['area_highschool_ratio'] = sorted_data1['area_highschool_ratio'] / max(sorted_data1['area_highschool_ratio'])

# %%
sorted_data1
# Out:
#    area_list  area_highschool_ratio
# 21        MA               1.000000
# 11        HI               0.996057
# 6         CT               0.995254
# 19        ME               0.993505
# 29        NH               0.985688
# 32        NY               0.983804
# 30        NJ               0.983615
# 49        WI               0.980827
# 26        MT               0.977878
# 45        VT               0.977707
# 15        IA               0.974321
# 44        UT               0.974097
# 27        NE               0.972769
# 23        MN               0.972151
# 8         DC               0.970352
# 22        MI               0.969349
# 38        PA               0.966797
# 5         CO               0.966290
# 39        RI               0.965191
# 7         DE               0.961871
# 13        IL               0.959371
# 35        OH               0.958390
# 20        MD               0.957107
# 16        KS               0.955877
# 37        OR               0.951900
# ...

# %%
data = pd.concat([sorted_data,sorted_data1['area_highschool_ratio']],axis=1)

# %%
data
# Out:
#    area_list  area_poverty_ratio  area_highschool_ratio
# 0         AL            0.766687               0.871072
# 1         AK            0.694778               0.870362
# 2         AZ            0.939884               0.860801
# 3         AR            0.854151               0.868748
# 4         CA            0.628188               0.878257
# 5         CO            0.490539               0.966290
# 6         CT            0.339883               0.995254
# 7         DE            0.467033               0.961871
# 8         DC            0.669537               0.970352
# 9         FL            0.651259               0.928600
# 10        GA            0.880204               0.854458
# 11        HI            0.498458               0.996057
# 12        ID            0.672372               0.917299
# 13        IL            0.515147               0.959371
# 14        IN            0.576540               0.937963
# 15        IA            0.454971               0.974321
# ...

# %%
f, ax1 = plt.subplots(figsize=(20,10))
sns.pointplot(x='area_list',y='area_poverty_ratio',data=data,color='lime',alpha=0.8)
sns.pointplot(x='area_list',y='area_highschool_ratio',data=data,color='red',alpha=0.8)
plt.text(40,0.6,'고등학교 졸업율',color='red',fontsize=18, style='italic')
plt.text(40,0.55,'빈곤율',color='lime',fontsize=18, style='italic')
plt.xlabel('미국의 각주',fontsize=18, color='blue')
plt.ylabel('수치',fontsize=18, color='blue')
plt.title('고등학교 졸업율 vs 빈곤율', fontsize=18, color='blue')
plt.grid()

# %%
g=sns.jointplot(data.area_poverty_ratio,data.area_highschool_ratio, kind='kde',size=5)
plt.xlabel('빈곤율',fontsize=18, color='blue')
plt.ylabel('고등학교 졸업율',fontsize=18, color='blue')
plt.savefig('graph.png')#그래프 저장
plt.show()
# Out:
# C:\Users\w\AppData\Local\Programs\Python\Python36\lib\site-packages\seaborn\axisgrid.py:2264: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
g=sns.jointplot(data.area_poverty_ratio,data.area_highschool_ratio, data=data, size=5, ratio=3, color='r')
plt.xlabel('빈곤율',fontsize=18, color='blue')
plt.ylabel('고등학교 졸업율',fontsize=18, color='blue')
plt.show()
# Out:
# C:\Users\w\AppData\Local\Programs\Python\Python36\lib\site-packages\seaborn\axisgrid.py:2264: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
